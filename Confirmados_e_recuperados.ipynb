# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedroviniciusdejesus/Modelos-Log-sticos/blob/main/Confirmados_e_recuperados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Insira os dados
X = np.array([4, 5, 21, 67, 115, 161, 238, 276, 357, 448, 511, 539, 604, 627, 650, 667, 670, 678, 697, 701, 709, 712, 716, 725, 733, 738, 742, 745, 745, 745, 745, 745, 745, 745, 745, 747, 748, 756, 765, 772, 788, 904, 997, 1035, 1091, 1149, 1230, 1317, 1361, 1361, 1377, 1401, 1405, 1409, 1418, 1426, 1429, 1432, 1441, 1443, 1446, 1446, 1447, 1448, 1449, 1449, 1449, 1449, 1450, 1459, 1459, 1459, 1459, 1460, 1460, 1460, 1460, 1460, 1461, 1470, 1470, 1473, 1475, 1475, 1476, 1479, 1479, 1522, 1708, 1961, 2040, 2074, 2079, 2080, 2080, 2080, 2183])

Y = np.array([0, 2, 3, 5, 25, 28, 74, 140, 221, 314, 383, 454, 502, 554, 608, 625, 640, 661, 663, 670, 677, 682, 702, 706, 711, 716, 721, 726, 727, 727, 727, 727, 735, 737, 737, 737, 738, 746, 748, 750, 761, 787, 797, 834, 867, 933, 966, 1169, 1209, 1250, 1290, 1312, 1322, 1352, 1352, 1352, 1352, 1352, 1352, 1352, 1384, 1409, 1414, 1420, 1420, 1420, 1420, 1420, 1420, 1428, 1430, 1431, 1433, 1435, 1435, 1436, 1436, 1436, 1436, 1436, 1439, 1446, 1446, 1446, 1451, 1451, 1451, 1455, 1455, 1644, 1912, 1989, 2036, 2051, 2053, 2056, 2158])

slope, intercept, r_value, p_value, std_err = linregress(X, Y)

# Calcular os valores preditos
predicted_Y = slope * X + intercept

# Plotar os dados e a linha de ajuste linear
plt.scatter(X, Y, label='Dados reais')
plt.plot(X, predicted_Y, color='red', label='Ajuste Linear')

# Adicionar rótulos e legenda
plt.xlabel('Casos Confirmados (X)')
plt.ylabel('Recuperados (Y)')
plt.legend()

# Exibir o gráfico
plt.show()

# Imprimir os resultados
print(f"Ajuste Linear: Y = {slope:.4f} * X + {intercept:.4f}")
print(f"Coeficiente de Correlação de Pearson (r): {r_value:.4f}")
print(f"Erro Padrão da Estimativa: {std_err:.4f}")

from scipy.stats import t

# Calcular o valor crítico para um nível de significância de 0,05 (bilateral)
alpha = 0.05
df = len(X) - 2  # graus de liberdade
t_critical = t.ppf(1 - alpha/2, df)

# Calcular o valor t
t_statistic = r_value * np.sqrt(df) / np.sqrt(1 - r_value**2)

# Verificar se rejeita H0
if np.abs(t_statistic) > t_critical:
    print("Rejeitar H0: Existe uma correlação significativa.")
else:
    print("Não rejeitar H0: Não há evidências suficientes para afirmar uma correlação significativa.")

# Supondo que você tenha duas listas de dados X e Y
n = len(X)
df = n - 2

print(f"Graus de liberdade: {df}")


# Calcular o R²
mean_Y = np.mean(Y)
r_squared = 1 - np.sum((Y - predicted_Y)**2) / np.sum((Y - mean_Y)**2)

print(f"Coeficiente de Determinação (R²): {r_squared:.4f}")
# Imprimir o valor t
print(f"Valor da estatística de teste (t): {t_statistic}")

# Calcule o valor crítico para um teste bicaudal
t_critical = t.ppf(1 - alpha/2, df)

# Imprima o valor crítico
print(f"Valor Crítico para alpha = {alpha}: {t_critical}")
# Out:
# Ajuste Linear: Y = 0.9921 * X + -53.7369
# Coeficiente de Correlação de Pearson (r): 0.9927
# Erro Padrão da Estimativa: 0.0124
# Rejeitar H0: Existe uma correlação significativa.
# Graus de liberdade: 95
# Coeficiente de Determinação (R²): 0.9854
# Valor da estatística de teste (t): 80.01651703452107
# Valor Crítico para alpha = 0.05: 1.9852510034099262

# %%
# Out:
# Rejeitar H0: Existe uma correlação significativa.
